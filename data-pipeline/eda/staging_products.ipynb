# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
load_dotenv("../.env")

pg_host = os.getenv("PG_HOST", "")
pg_port = os.getenv("PG_PORT", "")
pg_user = os.getenv("PG_USER", "")
pg_password = os.getenv("PG_PASSWORD", "")
pg_database = os.getenv("PG_DATABASE", "")
pg_connection = f"postgresql://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_database}?sslmode=disable"

engine = create_engine(pg_connection)

# %%
# %load_ext sql
# %config SqlMagic.autocommit = False
# %config SqlMagic.displaylimit = 50
# %sql engine
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml

# %% [markdown]
# # products overview

# %%
# %sql SELECT * FROM staging.products
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/myorg?sslmode=disable'
# 400 rows affected.
# +------------+-------------------------------------+---------------+--------------------------------+-----------------------+--------------------+--------+--------------------+----------------+
# | product_id |             product_name            | category_name |      product_description       | product_standard_cost | product_list_price | profit |    _dlt_load_id    |    _dlt_id     |
# +------------+-------------------------------------+---------------+--------------------------------+-----------------------+--------------------+--------+--------------------+----------------+
# |    P001    |   Intel Xeon E5-2699 V3 (OEM/Tray)  |      CPU      | Speed:2.3GHz,Cores:18,TDP:145W |        2867.51        |      3410.46       | 542.95 | 1757254089.4077978 | pG8W2gBKVx4ZsA |
# |    P002    |        Intel Xeon E5-2697 V3        |      CPU      |     Speed:2.6GHz,Cores:14      |        2326.27        |      2774.98       | 448.71 | 1757254089.4077978 | 63MqqLLS4gPbWg |
# |    P003    |   Intel Xeon E5-2698 V3 (OEM/Tray)  |      CPU      |          Speed:2.3GHz          |        2035.18        |      2660.72       | 625.54 | 1757254089.4077978 | kdj0WGFe+1DTiQ |
# |    P004    |        Intel Xeon E5-2697 V4        |      CPU      |       Cores:18,TDP:145W        |         2144.4        |      2554.99       | 410.59 | 1757254089.4077978 | QAjp1bIXJuJhag |
# |    P005    |   Intel Xeon E5-2685 V3 (OEM/Tray)  |      CPU      |     Speed:2.6GHz,Cores:12      |        2012.11        |      2501.69       | 489.58 | 1757254089.4077978 | J0qj3cUzSH4+Zg |
# |    P006    |   Intel Xeon E5-2695 V3 (OEM/Tray)  |      CPU      |     Speed:2.3GHz,Cores:14      |        1925.13        |      2431.95       | 506.82 | 1757254089.4077978 | rAHr3uE7snBSbQ |
# |    P007    |        Intel Xeon E5-2697 V2        |      CPU      | Speed:2.7GHz,Cores:12,TDP:130W |        2101.59        |      2377.09       | 275.5  | 1757254089.4077978 | vzDBHRYj2Q3ASg |
# |    P008    |        Intel Xeon E5-2695 V4        |      CPU      | Speed:2.1GHz,Cores:18,TDP:120W |        1780.35        |      2269.99       | 489.64 | 1757254089.4077978 | zdx/GDuIpXMc7w |
# |    P009    |        Intel Xeon E5-2695 V2        |      CPU      | Speed:2.4GHz,Cores:12,TDP:115W |        1793.53        |      2259.99       | 466.46 | 1757254089.4077978 | 89E0vCPFCiOXNw |
# |    P010    |   Intel Xeon E5-2643 V2 (OEM/Tray)  |      CPU      |      Speed:3.5GHz,Cores:6      |        1940.18        |       2200.0       | 259.82 | 1757254089.4077978 | ag2G9KgacGDZxg |
# |    P011    |    Intel Xeon E5-2690 (OEM/Tray)    |      CPU      |      Speed:2.9GHz,Cores:8      |        1888.33        |      2116.72       | 228.39 | 1757254089.4077978 | +UF8STJhQ45/Qw |
# |    P012    |        Intel Xeon E5-2687W V3       |      CPU      | Speed:3.1GHz,Cores:10,TDP:160W |        1781.47        |      2064.99       | 283.52 | 1757254089.4077978 | ibdUM8eC0jI2sg |
# |    P013    |        Intel Xeon E5-2687W V4       |      CPU      | Speed:3.0GHz,Cores:12,TDP:160W |        1723.83        |      2042.69       | 318.86 | 1757254089.4077978 | /SOPmG//nTExtw |
# |    P014    |   Intel Xeon E5-2667 V3 (OEM/Tray)  |      CPU      | Speed:3.2GHz,Cores:8,TDP:135W  |        1504.08        |      2009.46       | 505.38 | 1757254089.4077978 | JhlGDJMCewIxqg |
# |    P015    |        Intel Xeon E5-2690 V4        |      CPU      | Speed:2.6GHz,Cores:14,TDP:135W |        1499.26        |      1994.49       | 495.23 | 1757254089.4077978 | rSumOu/OChpTog |
# |    P016    |        Intel Xeon E5-2690 V3        |      CPU      | Speed:2.6GHz,Cores:12,TDP:135W |        1540.35        |      1908.73       | 368.38 | 1757254089.4077978 | dCW0I3vPW7rISQ |
# |    P017    |         Intel Xeon E5-2470V2        |      CPU      | Speed:2.4GHz,Cores:10,TDP:95W  |        1671.95        |       1904.7       | 232.75 | 1757254089.4077978 | 0an5CgNJB2OdjA |
# |    P018    |        Intel Xeon E5-2683 V4        |      CPU      | Speed:2.1GHz,Cores:16,TDP:120W |        1706.95        |      1899.99       | 193.04 | 1757254089.4077978 | uIcIuxJCQsBBVg |
# |    P019    |   Intel Xeon E5-2637 V2 (OEM/Tray)  |      CPU      | Speed:3.5GHz,Cores:4,TDP:130W  |        1323.12        |       1850.0       | 526.88 | 1757254089.4077978 | qINf1iWuTWUL6A |
# |    P020    |   Intel Xeon E5-2683 V4 (OEM/Tray)  |      CPU      | Speed:2.1GHz,Cores:16,TDP:120W |        1369.83        |      1844.89       | 475.06 | 1757254089.4077978 | WEx5OYRkikvfqg |
# |    P021    | Intel Core i7-4960X Extreme Edition |      CPU      | Speed:3.6GHz,Cores:6,TDP:130W  |        1496.43        |      1805.97       | 309.54 | 1757254089.4077978 | JBiot2/prcM9CA |
# |    P022    |   Intel Xeon E5-2699 V4 (OEM/Tray)  |      CPU      | Speed:2.2GHz,Cores:22,TDP:145W |        1535.62        |       1756.0       | 220.38 | 1757254089.4077978 | kSjVuRElrojy/Q |
# |    P023    |   Intel Xeon E5-1680 V3 (OEM/Tray)  |      CPU      | Speed:3.2GHz,Cores:8,TDP:140W  |        1519.85        |      1751.99       | 232.14 | 1757254089.4077978 | ApAQ3Gpbfth7Ug |
# |    P024    |   Intel Xeon E5-2643 V4 (OEM/Tray)  |      CPU      | Speed:3.4GHz,Cores:6,TDP:135W  |        1225.59        |      1708.86       | 483.27 | 1757254089.4077978 | Td1IpF++kpco9Q |
# |    P025    |    Intel Core i7-6950X (OEM/Tray)   |      CPU      | Speed:3.0GHz,Cores:10,TDP:140W |        1479.56        |      1704.37       | 224.81 | 1757254089.4077978 | ujOjFZhcE3C/CA |
# |    P026    |        Intel Xeon E5-2670 V3        |      CPU      | Speed:2.3GHz,Cores:12,TDP:120W |        1453.94        |      1676.98       | 223.04 | 1757254089.4077978 | ReJ3J5f3M1AJgQ |
# |    P027    |          Intel Xeon E5-2680         |      CPU      | Speed:2.7GHz,Cores:8,TDP:130W  |        1479.95        |      1666.61       | 186.66 | 1757254089.4077978 | BiHkZfgKimwTkw |
# |    P028    |        Intel Xeon E5-2680 V4        |      CPU      | Speed:2.4GHz,Cores:14,TDP:120W |        1365.13        |      1639.99       | 274.86 | 1757254089.4077978 | EWgHRxAVBNqhNQ |
# |    P029    |   Intel Xeon E5-2680 V3 (OEM/Tray)  |      CPU      | Speed:2.5GHz,Cores:12,TDP:120W |        1166.89        |      1638.89       | 472.0  | 1757254089.4077978 | DRKCNr/1m+J/pQ |
# |    P030    |         Intel Core i7-6950X         |      CPU      | Speed:3.0GHz,Cores:10,TDP:140W |        1052.92        |      1499.89       | 446.97 | 1757254089.4077978 | A4Wj6vJs/t42Rg |
# |    P031    |   Intel Xeon E5-2643 V3 (OEM/Tray)  |      CPU      | Speed:3.4GHz,Cores:6,TDP:135W  |        1266.37        |      1469.96       | 203.59 | 1757254089.4077978 | dQV7uzhuIXcnig |
# |    P032    |        Intel Xeon E5-2660 V4        |      CPU      | Speed:2.0GHz,Cores:14,TDP:105W |        1194.03        |      1388.89       | 194.86 | 1757254089.4077978 | mcG4aLAlzlI0pA |
# |    P033    |        Intel Xeon E5-2660 V3        |      CPU      | Speed:2.6GHz,Cores:10,TDP:105W |        1041.99        |      1299.73       | 257.74 | 1757254089.4077978 | tlyfu2M3ythaaQ |
# |    P034    |   Intel Xeon E5-2660 V3 (OEM/Tray)  |      CPU      |     Speed:2.6GHz,Cores:10      |         902.18        |      1274.99       | 372.81 | 1757254089.4077978 | rAfm1y8NTSrIbw |
# |    P035    |        Intel Xeon E5-2650 V2        |      CPU      |      Speed:2.6GHz,Cores:8      |         961.11        |       1249.0       | 287.89 | 1757254089.4077978 | 5Z/uUL8gvKC2tA |
# |    P036    |        Intel Xeon E5-2650 V3        |      CPU      |     Speed:2.3GHz,Cores:10      |         906.63        |      1204.98       | 298.35 | 1757254089.4077978 | NiXrh5QwOgOjug |
# |    P037    |  Intel Core i7-990X Extreme Edition |      CPU      |     Speed:3.47GHz,Cores:6      |        1072.79        |      1199.99       | 127.2  | 1757254089.4077978 | r6/B4jP/Cv3VMw |
# |    P038    |        Intel Xeon E5-2650 V4        |      CPU      |     Speed:2.2GHz,Cores:12      |         945.11        |      1099.99       | 154.88 | 1757254089.4077978 | IQXEheCSljO76A |
# |    P039    |          Intel Xeon E5-2650         |      CPU      |      Speed:2.0GHz,Cores:8      |         869.03        |      1064.99       | 195.96 | 1757254089.4077978 | gSmy0BOkIJ073Q |
# |    P040    |         Intel Core i9-7900X         |      CPU      |     Speed:3.3GHz,Cores:10      |         855.82        |      1029.99       | 174.17 | 1757254089.4077978 | 6ANxDXx2El1MXg |
# |    P041    |   Intel Xeon E5-1660 V3 (OEM/Tray)  |      CPU      |      Speed:3.0GHz,Cores:8      |         914.52        |      1019.99       | 105.47 | 1757254089.4077978 | F5a9C9MCVcCPSQ |
# |    P042    |  Intel Xeon E5-2650L V3 (OEM/Tray)  |      CPU      |     Speed:1.8GHz,Cores:12      |         779.17        |      1010.46       | 231.29 | 1757254089.4077978 | 6b2waat7NKv35g |
# |    P043    |         Intel Core i7-5960X         |      CPU      |      Speed:3.0GHz,Cores:8      |         865.59        |      1009.79       | 144.2  | 1757254089.4077978 | PQ3hcE+yW8QU+A |
# |    P044    |     Intel Core 2 Extreme QX6800     |      CPU      | Speed:2.93GHz,Cores:4,TDP:100W |         787.72        |      1003.98       | 216.26 | 1757254089.4077978 | sqtWQp8/7bbcoQ |
# |    P045    |    Intel Core i7-5960X (OEM/Tray)   |      CPU      | Speed:3.0GHz,Cores:8,TDP:140W  |         879.8         |       977.99       | 98.19  | 1757254089.4077978 | PTC1/OZQEb459A |
# |    P046    |   Intel Xeon E5-2650 V3 (OEM/Tray)  |      CPU      | Speed:2.3GHz,Cores:10,TDP:105W |         799.98        |       939.49       | 139.51 | 1757254089.4077978 | NzRGdBh28VPUTA |
# |    P047    |        Intel Xeon E5-2640 V4        |      CPU      |     Speed:2.4GHz,Cores:10      |         738.71        |       899.99       | 161.28 | 1757254089.4077978 | rO9YHZBKL/7Jkw |
# |    P048    |        Intel Xeon E5-2640 V3        |      CPU      |      Speed:2.6GHz,Cores:8      |         668.24        |       899.99       | 231.75 | 1757254089.4077978 | g2b3Tv93TMWsag |
# |    P049    |     Intel Core 2 Extreme QX9775     |      CPU      |          Speed:3.2GHz          |         737.68        |       892.0        | 154.32 | 1757254089.4077978 | TkgVLbV7s2Befg |
# |    P050    |         Intel Core i7-6900K         |      CPU      |      Speed:3.2GHz,Cores:8      |         792.89        |       889.89       |  97.0  | 1757254089.4077978 | KwxMR4+eqjSJ/w |
# +------------+-------------------------------------+---------------+--------------------------------+-----------------------+--------------------+--------+--------------------+----------------+
# Truncated to displaylimit of 50.

# %% [markdown]
# ## are the products unique?

# %%
# %sql SELECT product_name, COUNT(*) FROM staging.products GROUP BY product_name HAVING COUNT(*) > 1
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/myorg?sslmode=disable'
# /home/seya/code/01/data-warehouse/data-pipeline/.venv/lib/python3.12/site-packages/sql/connection/connection.py:881: JupySQLRollbackPerformed: Current transaction is aborted. JupySQL executed a ROLLBACK operation.
#   warnings.warn(
# 85 rows affected.
# +----------------------------------+-------+
# |           product_name           | count |
# +----------------------------------+-------+
# |      ASRock EP2C602-4L/D16       |   3   |
# |            HP C2J95AT            |   2   |
# |       Supermicro X10SAT-O        |   2   |
# |         PNY VCQM5000-PB          |   2   |
# |      EVGA Z270 Classified K      |   2   |
# |      ADATA ASU800SS-512GT-C      |   2   |
# |            MSI GAMING            |   2   |
# |    MSI Z170A KRAIT GAMING 3X     |   2   |
# |    SanDisk SDSSDHII-240G-G25     |   2   |
# |       Seagate ST2000DX002        |   2   |
# |       MSI X99A WORKSTATION       |   2   |
# |         PNY VCQK4200-PB          |   2   |
# |        ATI FirePro S9050         |   2   |
# |     Crucial CT1050MX300SSD1      |   2   |
# |      G.Skill Trident Z RGB       |   2   |
# |          AMD 100-506061          |   2   |
# |      Intel Xeon E5-2687W V4      |   2   |
# |       Samsung MZ-7KE256BW        |   2   |
# |   MSI GTX 1080 TI LIGHTNING Z    |   2   |
# |     MSI X299 TOMAHAWK ARCTIC     |   2   |
# |        AMD FirePro S7000         |   2   |
# |    Western Digital WD2003FZEX    |   2   |
# | Intel Xeon E5-2667 V3 (OEM/Tray) |   2   |
# |         EVGA Classified          |   2   |
# |    Western Digital WD1003FZEX    |   2   |
# |      MSI Z170A KRAIT GAMING      |   2   |
# |        Asus VANGUARD B85         |   2   |
# |     Gigabyte GA-X99-UD5 WIFI     |   2   |
# |      Intel Xeon E5-2687W V3      |   2   |
# |         PNY VCQP5000-PB          |   2   |
# |      Intel SSDPECME040T401       |   2   |
# |       EVGA 12G-P4-1999-KR        |   2   |
# |      Intel Xeon E5-2683 V4       |   2   |
# |             Crucial              |   4   |
# |      Intel Xeon E5-2695 V2       |   2   |
# |  Intel Xeon E5-2690 (OEM/Tray)   |   2   |
# |       Samsung MZ-V6P1T0BW        |   2   |
# | Intel Xeon E5-2643 V2 (OEM/Tray) |   2   |
# |    Corsair Dominator Platinum    |   10  |
# |       Asus MAXIMUS IX CODE       |   2   |
# |         PNY VCQK6000-PB          |   2   |
# |      Crucial CT525MX300SSD1      |   2   |
# | MSI Z270 XPOWER GAMING TITANIUM  |   2   |
# |      PNY SSD7CS1311-120-RB       |   2   |
# |       PNY SSD9SC240GMDA-RB       |   2   |
# |       EVGA 12G-P4-3992-KR        |   2   |
# |      Corsair Vengeance LPX       |   8   |
# | Intel Xeon E5-2683 V4 (OEM/Tray) |   2   |
# |       Intel Xeon E5-2470V2       |   2   |
# |   MSI GTX 1080 TI LIGHTNING X    |   2   |
# +----------------------------------+-------+
# Truncated to displaylimit of 50.

# %% [markdown]
# ## does the data differ?

# %%
# %%sql
# SELECT p.product_id, product_name, category_name, product_standard_cost, product_list_price, profit, od.order_item_quantity, per_unit_price, o.order_date, name_count
# FROM (
#     SELECT p.*,
#            COUNT(*) OVER (PARTITION BY product_name) AS name_count
#     FROM staging.products p
# ) p
# LEFT JOIN staging.order_details od ON od.product_id = p.product_id
# LEFT JOIN staging.orders o ON od.order_id = o.order_id
# WHERE name_count > 1
# ORDER BY product_name, order_date
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/myorg?sslmode=disable'
# /home/seya/code/01/data-warehouse/data-pipeline/.venv/lib/python3.12/site-packages/sql/connection/connection.py:881: JupySQLRollbackPerformed: Current transaction is aborted. JupySQL executed a ROLLBACK operation.
#   warnings.warn(
# 210 rows affected.
# +------------+-----------------------------------------+---------------+-----------------------+--------------------+--------+---------------------+----------------+------------+------------+
# | product_id |               product_name              | category_name | product_standard_cost | product_list_price | profit | order_item_quantity | per_unit_price | order_date | name_count |
# +------------+-----------------------------------------+---------------+-----------------------+--------------------+--------+---------------------+----------------+------------+------------+
# |    P347    |          ADATA ASU800SS-512GT-C         |    Storage    |        7123.66        |      7123.66       |  0.0   |          80         |     59.99      | 2015/12/14 |     2      |
# |    P258    |          ADATA ASU800SS-512GT-C         |    Storage    |        7123.66        |      7123.66       |  0.0   |          72         |     811.99     | 2017/09/27 |     2      |
# |    P389    |             AMD 100-5056062             |   Video Card  |        1343.84        |      1499.99       | 156.15 |          99         |     57.98      | 2017/01/24 |     2      |
# |    P085    |             AMD 100-5056062             |   Video Card  |        1343.84        |      1499.99       | 156.15 |         130         |     482.49     | 2017/02/10 |     2      |
# |    P078    |              AMD 100-505989             |   Video Card  |        2128.67        |      2699.99       | 571.32 |         127         |    2042.69     | 2016/06/14 |     2      |
# |    P382    |              AMD 100-505989             |   Video Card  |        2128.67        |      2699.99       | 571.32 |          51         |     588.95     | 2017/01/05 |     2      |
# |    P392    |              AMD 100-506061             |   Video Card  |         706.99        |       999.99       | 293.0  |          37         |     549.59     | 2016/11/29 |     2      |
# |    P088    |              AMD 100-506061             |   Video Card  |         706.99        |       999.99       | 293.0  |         104         |     149.88     | 2017/01/02 |     2      |
# |    P391    |            AMD FirePro S7000            |   Video Card  |         936.42        |       1218.5       | 282.08 |         147         |     811.99     | 2016/11/29 |     2      |
# |    P087    |            AMD FirePro S7000            |   Video Card  |         936.42        |       1218.5       | 282.08 |          61         |     647.99     | 2017/02/10 |     2      |
# |    P221    |          ASRock EP2C602-4L/D16          |  Mother Board |         225.47        |       301.99       | 76.52  |          35         |     731.99     | 2016/06/30 |     3      |
# |    P365    |          ASRock EP2C602-4L/D16          |  Mother Board |         225.47        |       301.99       | 76.52  |         132         |    1199.99     | 2017/02/10 |     3      |
# |    P380    |          ASRock EP2C602-4L/D16          |  Mother Board |         227.48        |       280.98       |  53.5  |          59         |    2290.79     | 2017/03/18 |     3      |
# |    P233    |            ASRock X299 Taichi           |  Mother Board |         214.36        |       282.98       | 68.62  |          45         |     329.99     | 2016/02/17 |     2      |
# |    P377    |            ASRock X299 Taichi           |  Mother Board |         214.36        |       282.98       | 68.62  |          83         |     579.99     | 2016/09/19 |     2      |
# |    P089    |            ATI FirePro R5000            |   Video Card  |         760.59        |       999.99       | 239.4  |         143         |     695.99     | 2015/12/14 |     2      |
# |    P393    |            ATI FirePro R5000            |   Video Card  |         760.59        |       999.99       | 239.4  |         114         |     588.95     | 2017/09/28 |     2      |
# |    P084    |            ATI FirePro S9050            |   Video Card  |        1237.04        |       1699.0       | 461.96 |         114         |     798.26     | 2016/02/17 |     2      |
# |    P388    |            ATI FirePro S9050            |   Video Card  |        1237.04        |       1699.0       | 461.96 |         144         |    1199.99     | 2017/02/14 |     2      |
# |    P395    |            Asus GTX780TI-3GD5           |   Video Card  |         781.91        |       899.99       | 118.08 |          82         |     280.98     | 2016/09/27 |     2      |
# |    P091    |            Asus GTX780TI-3GD5           |   Video Card  |         781.91        |       899.99       | 118.08 |          98         |    1899.99     | 2016/12/01 |     2      |
# |    P225    |           Asus MAXIMUS IX CODE          |  Mother Board |         266.15        |       298.98       | 32.83  |         112         |     579.99     | 2013/06/21 |     2      |
# |    P369    |           Asus MAXIMUS IX CODE          |  Mother Board |         266.15        |       298.98       | 32.83  |          49         |     799.0      | 2015/12/01 |     2      |
# |    P219    |            Asus PRIME X299-A            |  Mother Board |         274.56        |       309.85       | 35.29  |         144         |    1073.99     | 2015/06/29 |     2      |
# |    P363    |            Asus PRIME X299-A            |  Mother Board |         274.56        |       309.85       | 35.29  |         140         |     722.99     | 2016/02/17 |     2      |
# |    P361    |        Asus ROG STRIX X99 GAMING        |  Mother Board |         255.86        |       319.99       | 64.13  |         113         |     388.99     | 2017/02/21 |     2      |
# |    P217    |        Asus ROG STRIX X99 GAMING        |  Mother Board |         255.86        |       319.99       | 64.13  |          73         |     704.99     | 2017/08/24 |     2      |
# |    P397    | Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING |   Video Card  |         696.14        |       864.98       | 168.84 |          66         |     798.26     | 2016/08/16 |     2      |
# |    P093    | Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING |   Video Card  |         696.14        |       864.98       | 168.84 |         146         |     873.98     | 2017/11/01 |     2      |
# |    P226    |          Asus Sabertooth 990FX          |  Mother Board |         252.31        |       295.72       | 43.41  |          75         |    1055.99     | 2016/06/21 |     2      |
# |    P370    |          Asus Sabertooth 990FX          |  Mother Board |         252.31        |       295.72       | 43.41  |         112         |     644.0      | 2016/12/01 |     2      |
# |    P373    |            Asus VANGUARD B85            |  Mother Board |         258.1         |       287.0        |  28.9  |          58         |     287.0      | 2015/10/27 |     2      |
# |    P229    |            Asus VANGUARD B85            |  Mother Board |         258.1         |       287.0        |  28.9  |         134         |    1899.99     | 2017/03/17 |     2      |
# |    P160    |        Corsair Dominator Platinum       |    Storage    |         578.46        |       699.89       | 121.43 |          70         |     469.99     | 2015/10/27 |     10     |
# |    P129    |        Corsair Dominator Platinum       |    Storage    |        1068.66        |      1264.99       | 196.33 |          77         |     686.99     | 2016/02/17 |     10     |
# |    P145    |        Corsair Dominator Platinum       |    Storage    |         609.89        |       749.99       | 140.1  |          62         |    1499.89     | 2016/06/13 |     10     |
# |    P123    |        Corsair Dominator Platinum       |    Storage    |        1051.97        |      1449.99       | 398.02 |          70         |     149.88     | 2016/06/14 |     10     |
# |    P169    |        Corsair Dominator Platinum       |    Storage    |         537.63        |       659.99       | 122.36 |          42         |    2774.98     | 2017/01/05 |     10     |
# |    P152    |        Corsair Dominator Platinum       |    Storage    |         616.53        |       719.99       | 103.46 |         108         |     1249.0     | 2017/02/10 |     10     |
# |    P131    |        Corsair Dominator Platinum       |    Storage    |        1002.47        |      1199.99       | 197.52 |          45         |     725.99     | 2017/02/10 |     10     |
# |    P153    |        Corsair Dominator Platinum       |    Storage    |         538.55        |       719.99       | 181.44 |         131         |     635.99     | 2017/02/10 |     10     |
# |    P127    |        Corsair Dominator Platinum       |    Storage    |        1131.68        |      1314.99       | 183.31 |          74         |     734.99     | 2017/02/21 |     10     |
# |    P138    |        Corsair Dominator Platinum       |    Storage    |         700.5         |       804.99       | 104.49 |          78         |     299.89     | 2017/11/01 |     10     |
# |    P161    |          Corsair Vengeance LPX          |    Storage    |         595.42        |       699.01       | 103.59 |          32         |     892.0      | 2015/10/28 |     8      |
# |    P128    |          Corsair Vengeance LPX          |    Storage    |         912.98        |      1299.99       | 387.01 |         116         |     443.72     | 2016/02/17 |     8      |
# |    P172    |          Corsair Vengeance LPX          |    Storage    |         571.7         |       645.99       | 74.29  |          38         |     1756.0     | 2016/11/17 |     8      |
# |    P133    |          Corsair Vengeance LPX          |    Storage    |         821.91        |      1099.99       | 278.08 |         123         |     68.06      | 2017/01/02 |     8      |
# |    P130    |          Corsair Vengeance LPX          |    Storage    |        1019.51        |      1199.99       | 180.48 |          65         |     16.99      | 2017/02/10 |     8      |
# |    P132    |          Corsair Vengeance LPX          |    Storage    |         867.52        |      1163.99       | 296.47 |          70         |     824.98     | 2017/02/10 |     8      |
# |    P147    |          Corsair Vengeance LPX          |    Storage    |         609.53        |       734.99       | 125.46 |          33         |     1249.0     | 2017/02/21 |     8      |
# +------------+-----------------------------------------+---------------+-----------------------+--------------------+--------+---------------------+----------------+------------+------------+
# Truncated to displaylimit of 50.

# %%
# %sql SELECT * FROM staging.products WHERE profit = 0
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/myorg?sslmode=disable'
# 43 rows affected.
# +------------+-----------------------------+---------------+--------------------------------------------------------------+-----------------------+--------------------+--------+--------------------+----------------+
# | product_id |         product_name        | category_name |                     product_description                      | product_standard_cost | product_list_price | profit |    _dlt_load_id    |    _dlt_id     |
# +------------+-----------------------------+---------------+--------------------------------------------------------------+-----------------------+--------------------+--------+--------------------+----------------+
# |    P252    |    Intel SSDPECME040T401    |    Storage    |       Series:DC P3608,Type:SSD,Capacity:4TB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | dNWTGXAxBjqX7Q |
# |    P253    |  Western Digital WD2003FZEX |    Storage    |   Series:BLACK SERIES,Type:7200RPM,Capacity:2TB,Cache:64MB   |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | 1p3OfrIZFk/Z1A |
# |    P254    |     Samsung MZ-V6P512BW     |    Storage    |      Series:960 PRO,Type:SSD,Capacity:512GB,Cache:512MB      |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | LfNvhMzJrU/pvA |
# |    P255    |   Hitachi HUS724030ALE641   |    Storage    | Series:Ultrastar 7K4000,Type:7200RPM,Capacity:3TB,Cache:64MB |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | krxR8xAN5Pbd6A |
# |    P256    |     Samsung MZ-V6P2T0BW     |    Storage    |        Series:960 Pro,Type:SSD,Capacity:2TB,Cache:2GB        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | ohe121mHXEC4GQ |
# |    P257    |    Seagate ST10000DM0004    |    Storage    | Series:BarraCuda Pro,Type:7200RPM,Capacity:10TB,Cache:256MB  |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | e36ZXr/WJcF/Sg |
# |    P258    |    ADATA ASU800SS-512GT-C   |    Storage    |   Series:Ultimate SU800,Type:SSD,Capacity:512GB,Cache:N/A    |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | mm1iw02pI0v8bQ |
# |    P259    |      Samsung MZ-V6E1T0      |    Storage    |      Series:960 EVO,Type:SSD,Capacity:1TB,Cache:1000MB       |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | hnjNUY37J3HNAw |
# |    P260    |  Western Digital WD1003FZEX |    Storage    |   Series:BLACK SERIES,Type:7200RPM,Capacity:1TB,Cache:64MB   |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | OeaG+8e8gXEOnA |
# |    P261    |   SanDisk SDSSDA-120G-G26   |    Storage    |                   Series:SSD PLUS,Type:SSD                   |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | Q3UdTskozbrhHA |
# |    P262    |    Crucial CT525MX300SSD1   |    Storage    |        Series:MX300,Type:SSD,Capacity:525GB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | CDcqScAscWjigw |
# |    P263    |     Hitachi A7K1000-1000    |    Storage    |    Series:Ultrastar,Type:7200RPM,Capacity:1TB,Cache:32MB     |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | oNz07/MFDtlxAQ |
# |    P264    |     Samsung MZ-V6P1T0BW     |    Storage    |        Series:960 Pro,Type:SSD,Capacity:1TB,Cache:1GB        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | 5QXW4O2aWUOFgw |
# |    P265    |     Samsung MZ-7KE256BW     |    Storage    |   Series:850 Pro Series,Type:SSD,Capacity:256GB,Cache:N/A    |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | z9RqeWFIB64XFw |
# |    P266    |     Seagate ST2000DX002     |    Storage    |     Series:FireCuda,Type:Hybrid,Capacity:2TB,Cache:64MB      |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | GCcY5U+hI0QgLQ |
# |    P267    |  Western Digital WD5000AACS |    Storage    |  Series:Caviar Green,Type:5400RPM,Capacity:500GB,Cache:16MB  |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | n8ERcpwgM/pgFQ |
# |    P268    |  SanDisk SDSSDHII-240G-G25  |    Storage    |      Series:Ultra II,Type:SSD,Capacity:240GB,Cache:N/A       |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | lAAV+UnBxzqi+Q |
# |    P269    |    PNY SSD7CS1311-120-RB    |    Storage    |       Series:CS1311,Type:SSD,Capacity:120GB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | HzjKzSSn28QW4g |
# |    P270    |     PNY SSD9SC240GMDA-RB    |    Storage    |        Series:XLR8,Type:SSD,Capacity:240GB,Cache:N/A         |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | tM1Bc/JOJlte0Q |
# |    P271    |   Crucial CT1050MX300SSD1   |    Storage    |        Series:MX300,Type:SSD,Capacity:1.1TB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | aTNnZwdzC0hkHw |
# |    P272    | Western Digital WDS250G1B0B |    Storage    |        Series:Blue,Type:SSD,Capacity:250GB,Cache:N/A         |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | ru9teWvHpnE7Xg |
# |    P314    |     Hynix 6671G DDR2 1GB    |      RAM      |    Series:Genuine, Type:DDR2, Capacity:1GB, Frequency:N/A    |         330.0         |       330.0        |  0.0   | 1757254089.4077978 | nxlcItuzwrlEBw |
# |    P318    |   Hynix (HYMD2GB) 2GB DDR2  |      RAM      |       Series:2, Type:DDR2, Capacity:2GB, Frequency:N/A       |         498.0         |       498.0        |  0.0   | 1757254089.4077978 | hFpG+NnIG2kcBA |
# |    P341    |    Intel SSDPECME040T401    |    Storage    |       Series:DC P3608,Type:SSD,Capacity:4TB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | 0mKIHrwgTDpB7A |
# |    P342    |  Western Digital WD2003FZEX |    Storage    |   Series:BLACK SERIES,Type:7200RPM,Capacity:2TB,Cache:64MB   |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | vRqG59iTEqKAYQ |
# |    P343    |     Samsung MZ-V6P512BW     |    Storage    |      Series:960 PRO,Type:SSD,Capacity:512GB,Cache:512MB      |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | dHm5FO+zNIKFTQ |
# |    P344    |   Hitachi HUS724030ALE641   |    Storage    | Series:Ultrastar 7K4000,Type:7200RPM,Capacity:3TB,Cache:64MB |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | kPA5N5oPaJ+p/Q |
# |    P345    |     Samsung MZ-V6P2T0BW     |    Storage    |        Series:960 Pro,Type:SSD,Capacity:2TB,Cache:2GB        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | xIkcEaAxEjVQpw |
# |    P346    |    Seagate ST10000DM0004    |    Storage    | Series:BarraCuda Pro,Type:7200RPM,Capacity:10TB,Cache:256MB  |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | z8gJFi1BWAUgFA |
# |    P347    |    ADATA ASU800SS-512GT-C   |    Storage    |   Series:Ultimate SU800,Type:SSD,Capacity:512GB,Cache:N/A    |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | OhdSuJnF2NGgXg |
# |    P348    |      Samsung MZ-V6E1T0      |    Storage    |      Series:960 EVO,Type:SSD,Capacity:1TB,Cache:1000MB       |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | 4kX5nSrYWh5H5w |
# |    P349    |  Western Digital WD1003FZEX |    Storage    |   Series:BLACK SERIES,Type:7200RPM,Capacity:1TB,Cache:64MB   |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | O6q8zvk6OIPCpA |
# |    P350    |   SanDisk SDSSDA-120G-G26   |    Storage    |                   Series:SSD PLUS,Type:SSD                   |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | WQG2Mxung3YqaA |
# |    P351    |    Crucial CT525MX300SSD1   |    Storage    |        Series:MX300,Type:SSD,Capacity:525GB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | lb5iTI2Qh84W9Q |
# |    P352    |     Hitachi A7K1000-1000    |    Storage    |    Series:Ultrastar,Type:7200RPM,Capacity:1TB,Cache:32MB     |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | nMzjnlYZPenWPg |
# |    P353    |     Samsung MZ-V6P1T0BW     |    Storage    |        Series:960 Pro,Type:SSD,Capacity:1TB,Cache:1GB        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | gRihptbMGyDc5g |
# |    P354    |     Samsung MZ-7KE256BW     |    Storage    |   Series:850 Pro Series,Type:SSD,Capacity:256GB,Cache:N/A    |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | fhCRi7jgUY1r7g |
# |    P355    |     Seagate ST2000DX002     |    Storage    |     Series:FireCuda,Type:Hybrid,Capacity:2TB,Cache:64MB      |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | miLbE9wK7swItg |
# |    P356    |  Western Digital WD5000AACS |    Storage    |  Series:Caviar Green,Type:5400RPM,Capacity:500GB,Cache:16MB  |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | A7TL7+NfOSFU5A |
# |    P357    |  SanDisk SDSSDHII-240G-G25  |    Storage    |      Series:Ultra II,Type:SSD,Capacity:240GB,Cache:N/A       |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | iPU21g4gbCgxUA |
# |    P358    |    PNY SSD7CS1311-120-RB    |    Storage    |       Series:CS1311,Type:SSD,Capacity:120GB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | 9NjHAtgtUbha/A |
# |    P359    |     PNY SSD9SC240GMDA-RB    |    Storage    |        Series:XLR8,Type:SSD,Capacity:240GB,Cache:N/A         |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | CjaM9aZbpP+C7A |
# |    P360    |   Crucial CT1050MX300SSD1   |    Storage    |        Series:MX300,Type:SSD,Capacity:1.1TB,Cache:N/A        |        7123.66        |      7123.66       |  0.0   | 1757254089.4077978 | J01LzC/4aNYz9A |
# +------------+-----------------------------+---------------+--------------------------------------------------------------+-----------------------+--------------------+--------+--------------------+----------------+

# %% [markdown]
# ## products conclusion
#
# - product_name is not unique
# - profit sometimes is 0
# -
